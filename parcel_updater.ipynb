# %%
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import sqlalchemy

# %%
#connection to the open payments in data in mysql
constr = 'mysql+mysqlconnector://root:mysqlroot@localhost:3306/pbgh_property'
engine = sqlalchemy.create_engine(constr,echo=False)

# %%
parcel_loc = 'https://data.wprdc.org/dataset/2b3df818-601e-4f06-b150-643557229491/resource/f2b8d575-e256-4718-94ad-1e12239ddb92/download/assessments.csv'
parcels = pd.read_csv(parcel_loc,dtype=str)

# %%
parcels.to_sql('allegheny_cty_parcels_2021',con=engine,if_exists='append',chunksize=1000)
# Out:
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\Users\henry\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 697, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\henry\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 893, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\henry\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py", line 2374, in do_rollback
#     dbapi_connection.rollback()
#   File "C:\Users\henry\anaconda3\lib\site-packages\mysql\connector\connection_cext.py", line 403, in rollback
#     self._cmysql.rollback()
# _mysql_connector.MySQLInterfaceError: MySQL server has gone away

# %%
sales_21 = parcels[parcels.SALEDATE.str[-4:] == '2021']
sales_21
# Out:
#                    PARID  PROPERTYHOUSENUM PROPERTYFRACTION  \
# 6       0001D00132000000             115.0             -119
# 33      0001G00126000000             116.0
# 97      0001G00224180100             151.0
# 101     0001G00224050200             151.0
# 129     0001H00181001000             223.0
# ...                  ...               ...              ...
# 580940  0325R00005000000               4.0
# 580960  0198B00009000000            6131.0
# 581005  0145S00024000000               1.0
# 581063  0148S00077000000             605.0
# 581068  0262N00025013000             130.0
#
#             PROPERTYADDRESS PROPERTYCITY PROPERTYSTATE PROPERTYUNIT  \
# 6                FORBES AVE   PITTSBURGH            PA
# 33      BLVD OF THE ALLIES    PITTSBURGH            PA
# 97           FORT PITT BLVD   PITTSBURGH            PA    UNIT 1801
# 101          FORT PITT BLVD   PITTSBURGH            PA     UNIT 502
# 129                 4TH AVE   PITTSBURGH            PA      UNIT 10
# ...                     ...          ...           ...          ...
# 580940        ALLEGHENY AVE        CUDDY            PA
# 580960         TURNBERRY DR       PRESTO            PA
# 581005            SUMMER DR  BRIDGEVILLE            PA
# 581063          PRESTLEY ST     CARNEGIE            PA
# 581068        BARRINGTON DR      OAKDALE            PA
#
#         PROPERTYZIP  MUNICODE                MUNIDESC  ...  HALFBATHS  \
# 6           15222.0       101  1st Ward  - PITTSBURGH  ...        NaN
# 33          15222.0       101  1st Ward  - PITTSBURGH  ...        NaN
# 97          15222.0       101  1st Ward  - PITTSBURGH  ...        NaN
# 101         15222.0       101  1st Ward  - PITTSBURGH  ...        1.0
# 129         15222.0       101  1st Ward  - PITTSBURGH  ...        NaN
# ...             ...       ...                     ...  ...        ...
# 580940      15031.0       946         South Fayette    ...        0.0
# 580960      15142.0       905               Collier    ...        2.0
# 581005      15017.0       905               Collier    ...        0.0
# 581063      15106.0       905               Collier    ...        0.0
# 581068      15071.0       905               Collier    ...        1.0
#
#        HEATINGCOOLING    HEATINGCOOLINGDESC FIREPLACES BSMTGARAGE  \
# 6                 NaN                   NaN        NaN        NaN
# 33                NaN                   NaN        NaN        NaN
# 97                  B  Central Heat with AC        NaN        0.0
# 101                 B  Central Heat with AC        NaN        NaN
# 129               NaN                   NaN        NaN        NaN
# ...               ...                   ...        ...        ...
# 580940              B  Central Heat with AC        0.0        1.0
# 580960              B  Central Heat with AC        NaN        NaN
# 581005              B  Central Heat with AC        0.0        1.0
# 581063              B  Central Heat with AC        0.0        1.0
# 581068              B  Central Heat with AC        0.0        0.0
#
#        FINISHEDLIVINGAREA CARDNUMBER            ALT_ID TAXYEAR   ASOFDATE
# 6                     NaN        NaN               NaN    2021  01-SEP-21
# 33                    NaN        NaN               NaN    2021  01-SEP-21
# 97                 1926.0        1.0               NaN    2021  01-SEP-21
# 101                1447.0        1.0               NaN    2021  01-SEP-21
# 129                   NaN        NaN               NaN    2021  01-SEP-21
# ...                   ...        ...               ...     ...        ...
# 580940             2032.0        1.0  9946X00032000000    2021  01-SEP-21
# 580960             6841.0        1.0  9905X83993000000    2021  01-SEP-21
# 581005             1261.0        1.0  9905X00619000000    2021  01-SEP-21
# 581063              815.0        1.0  9905X01216000000    2021  01-SEP-21
# 581068             1170.0        1.0  9905X83540000000    2021  01-SEP-21
#
# [20449 rows x 86 columns]

# %%
sales_21[sales_21.SALEDATE.str[:2] == '07']
# Out:
#                    PARID  PROPERTYHOUSENUM PROPERTYFRACTION  \
# 1020    0001C01662019700             320.0
# 1308    0025N00274000000            2310.0
# 1324    0009N00407000000             121.0
# 1516    0011E00173000000             223.0
# 2032    0009M00087000000            1709.0            -1711
# ...                  ...               ...              ...
# 579408  0098D00127000000            1326.0
# 579585  0032A00350000000             424.0
# 579678  0367A00035000000            1306.0
# 579932  0476M00110000000            2738.0
# 580690  0591P00260000000             123.0
#
#            PROPERTYADDRESS PROPERTYCITY PROPERTYSTATE PROPERTYUNIT  \
# 1020    FORT DUQUESNE BLVD   PITTSBURGH            PA    UNIT 19-G
# 1308              PENN AVE   PITTSBURGH            PA
# 1324                9TH ST   PITTSBURGH            PA
# 1516            LOMBARD ST   PITTSBURGH            PA
# 2032              CLIFF ST   PITTSBURGH            PA
# ...                    ...          ...           ...          ...
# 579408     MISSISSIPPI AVE   PITTSBURGH            PA
# 579585         OTTILLIA ST   PITTSBURGH            PA
# 579678           MAPLE AVE       VERONA            PA
# 579932             OHIO ST  BETHEL PARK            PA
# 580690       WESTBROOKE LN   CORAOPOLIS            PA
#
#         PROPERTYZIP  MUNICODE               MUNIDESC  ...  HALFBATHS  \
# 1020        15222.0       102  2nd Ward - PITTSBURGH  ...        0.0
# 1308        15222.0       102  2nd Ward - PITTSBURGH  ...        NaN
# 1324        15222.0       102  2nd Ward - PITTSBURGH  ...        1.0
# 1516        15219.0       103  3rd Ward - PITTSBURGH  ...        0.0
# 2032        15219.0       103  3rd Ward - PITTSBURGH  ...        NaN
# ...             ...       ...                    ...  ...        ...
# 579408      15216.0       819              Dormont    ...        0.0
# 579585      15210.0       839           Mt. Oliver    ...        0.0
# 579678      15147.0       934           Penn Hills    ...        1.0
# 579932      15102.0       876          Bethel Park    ...        0.0
# 580690      15108.0       910              Findlay    ...        1.0
#
#        HEATINGCOOLING    HEATINGCOOLINGDESC FIREPLACES BSMTGARAGE  \
# 1020                B  Central Heat with AC        0.0        0.0
# 1308              NaN                   NaN        NaN        NaN
# 1324                B  Central Heat with AC        NaN        NaN
# 1516                5             Unit Heat        0.0        0.0
# 2032              NaN                   NaN        NaN        NaN
# ...               ...                   ...        ...        ...
# 579408              2          Central Heat        0.0        0.0
# 579585              2          Central Heat        0.0        0.0
# 579678              B  Central Heat with AC        0.0        1.0
# 579932              B  Central Heat with AC        0.0        2.0
# 580690              B  Central Heat with AC        0.0        0.0
#
#        FINISHEDLIVINGAREA CARDNUMBER            ALT_ID TAXYEAR   ASOFDATE
# 1020                716.0        1.0               NaN    2021  01-SEP-21
# 1308                  NaN        NaN               NaN    2021  01-SEP-21
# 1324               2600.0        1.0               NaN    2021  01-SEP-21
# 1516               1268.0        1.0               NaN    2021  01-SEP-21
# 2032                  NaN        NaN               NaN    2021  01-SEP-21
# ...                   ...        ...               ...     ...        ...
# 579408             1894.0        1.0               NaN    2021  01-SEP-21
# 579585              834.0        1.0               NaN    2021  01-SEP-21
# 579678             1552.0        1.0               NaN    2021  01-SEP-21
# 579932             1376.0        1.0               NaN    2021  01-SEP-21
# 580690             1544.0        1.0  9910X84449000000    2021  01-SEP-21
#
# [2269 rows x 86 columns]
